# %% [markdown]
# # EIA API GET Request

# %%
import pandas as pd
import datetime
import requests
import os

# %%
eia_api_key = os.getenv('EIA_API_KEY')

# %%
request = "https://api.eia.gov/v2/electricity/rto/region-data/data/?frequency=hourly&data[0]=value&facets[respondent][]=US48&facets[type][]=D&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key=" + eia_api_key 

d = requests.get(request).json()

d
# Out:
# {'response': {'warnings': [{'warning': 'incomplete return',
#     'description': 'The API can only return 5000 rows in JSON format.  Please consider constraining your request with facet, start, or end, or using offset to paginate results.'}],
#   'total': '76911',
#   'dateFormat': 'YYYY-MM-DD"T"HH24',
#   'frequency': 'hourly',
#   'data': [{'period': '2024-04-08T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '423771',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '428223',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '429868',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '432064',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '431814',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '428620',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '425231',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '417458',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '396076',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '372147',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '359082',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '356816',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '360887.9',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '369176.9',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '381348.01',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '395455.85',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '410820.46',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '421810.37',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '424170',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-08T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '418721.86',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '413714.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '405909.76',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '397625.21',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '392799.31',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '392093.05',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '391488.75',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '392907.06',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '393195.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '393546.44',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '390671.53',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '388056.55',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '383661.46',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '375472.84',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '368807.46',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '366057.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '366585.26',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '371080.53',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '379071.33',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '388612.52',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '400150.21',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '411068.31',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '417820.21',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '416654.92',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-07T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '410312.37',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '406309.22',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '403584.55',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '399754.28',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '396810.62',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '397896.88',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '401182.32',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '405442.54',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '409396.81',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '412022.97',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '410467.43',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '407986.25',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '401423.35',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '390873.06',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '381138.1',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '376706.07',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '377865.38',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '382860.28',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '392257.93',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '404485.2',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '421031.26',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '435455.42',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445535.94',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '448694.64',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-06T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445870.25',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446311.76',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445189.67',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '441930.6',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '438229.4',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '438843.7',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '439188.22',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '442094.36',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '443920.25',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445302.46',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445925.19',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446056.71',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '438411.65',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '416850.91',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '394409.21',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '384475.52',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '382829.43',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '387711.15',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '397321.01',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '412160.11',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '429731.86',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446259.12',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '459825.1',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '462910.41',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-05T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '456689.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '451255.94',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446502.12',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '432814.93',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '440208.73',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '439312.85',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '440290.54',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '442295.72',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '444463.63',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446723.63',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '447451.15',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446230.77',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '436204.1',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '411877.2',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '388131.54',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '378241.15',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '377185.5',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '382181.82',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '390882.45',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '405008.61',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '422929.17',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '440651.5',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '453404.46',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '457291.81',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-04T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '453812.43',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '450732.33',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '449457.93',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446803.37',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446510.69',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '448655.47',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '450913.8',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '453721.63',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '455983.61',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '453962.51',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '448023.93',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '438787.35',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '423295.85',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '399543.49',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '377370.36',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '369640.01',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '369796.32',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '374769.18',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '386077.97',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '402553.4',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '422334.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '440410.07',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '455466.67',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '460596.29',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-03T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '460218.53',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '462500.21',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '462619.68',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '458595.12',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '456034.07',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '455163.35',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '454043.88',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '451737.93',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '448510.76',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445571.52',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '437853.03',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '427743.77',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '413728.58',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '392671.84',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '373346.98',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '366306.94',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '367346.63',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '373947.45',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '385374.21',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '401816.42',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '422155.52',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '442362.24',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '456172.9',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '462858.05',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-02T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '461493',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '459965.77',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '457386.01',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '452670.44',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '450182.51',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '447665.98',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '447502.64',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '446626.39',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445486.96',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '439915.13',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '430112.67',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '417077.14',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '400857.98',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '378990.17',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '359011.76',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '349701.49',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '350010.37',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '355176.32',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '364194.73',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '378153.56',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '393857.91',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '407437.26',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '416736.07',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '417165.67',
#     'value-units': 'megawatthours'},
#    {'period': '2024-04-01T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '410461.51',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '404903.17',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '399110.71',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '395394.31',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '392216.05',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '391771.07',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '393766.9',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '394167.67',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '391044.54',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '386848.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '379849.44',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '369612.54',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '358657.26',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '349621.22',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '344360',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '343539.49',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '347711.76',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '353678.07',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '364192.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '377964.32',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '393255.26',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '406539.3',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '415899.1',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '416880.1',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-31T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '413941.47',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '411987.82',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '407912.71',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '401247.66',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '395964.95',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '393989.61',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '394509.74',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '395576.62',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '395352.12',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '394052.64',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '391679.69',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '386731.41',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-30T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '378197.14',
#     'value-units': 'megawatthours'},
# ...
#     'value': '477962.2',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-01T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '492326.95',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-01T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '498888.96',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-01T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '497363.02',
#     'value-units': 'megawatthours'},
#    {'period': '2024-03-01T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '485867.58',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '471653.76',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '461747.54',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '458641.27',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '460812.49',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '465479.25',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '471254.35',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '478239.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '483808.4',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '488911.06',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '493290.52',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '488898.65',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '463960.32',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '434235.47',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '420914.19',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '416576.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '418621.58',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '424489.52',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '436167.86',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '449160.74',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '464089.93',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '476716.97',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '482024.13',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '481591.96',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-29T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '472339.76',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '461738.17',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '454448.43',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '453121.07',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '454628.25',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '456483.28',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '458660.91',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '461206.62',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '460082.36',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '455650.68',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '447554.97',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '433548.52',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '409479.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '385760.54',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '377248.44',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '376465.36',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '381629.48',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '390815.2',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '405347.31',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '424214.74',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '442728.93',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T03',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '457777.98',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T02',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '467510.67',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T01',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '470418.67',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-28T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '465607.86',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T23',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '458824.89',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '452388.15',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T21',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '447339.6',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T20',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445961.79',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T19',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '445206.03',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T18',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '443614.53',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T17',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '444834.36',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T16',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '443319.26',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T15',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '440697.36',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T14',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '439560.72',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T13',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '433874.38',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T12',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '412702.06',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T11',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '388115.94',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T10',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '378959.5',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T09',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '377968.42',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T08',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '381412.83',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T07',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '390345.62',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T06',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '404210.79',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T05',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '420928.87',
#     'value-units': 'megawatthours'},
#    {'period': '2024-02-27T04',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'type': 'D',
#     'type-name': 'Demand',
#     'value': '439744.04',
#     'value-units': 'megawatthours'},
#    ...],
#   'description': 'Hourly demand, day-ahead demand forecast, net generation, and interchange by balancing authority.  \n    Source: Form EIA-930\n    Product: Hourly Electric Grid Monitor'},
#  'request': {'command': '/v2/electricity/rto/region-data/data/',
#   'params': {'frequency': 'hourly',
#    'data': ['value'],
#    'facets': {'respondent': ['US48'], 'type': ['D']},
#    'sort': [{'column': 'period', 'direction': 'desc'}],
#    'offset': '0',
#    'length': '5000',
#    'api_key': '2X6aBAURvxdEyh1oTgGpmPa17MgjYpGws7Tg9msg'}},
#  'apiVersion': '2.1.6',
#  'ExcelAddInVersion': '2.1.0'}

# %%
df = pd.DataFrame(d['response']['data'])
df
# Out:
#              period respondent         respondent-name type type-name  \
# 0     2024-04-08T19       US48  United States Lower 48    D    Demand
# 1     2024-04-08T18       US48  United States Lower 48    D    Demand
# 2     2024-04-08T17       US48  United States Lower 48    D    Demand
# 3     2024-04-08T16       US48  United States Lower 48    D    Demand
# 4     2024-04-08T15       US48  United States Lower 48    D    Demand
# ...             ...        ...                     ...  ...       ...
# 4995  2023-09-13T16       US48  United States Lower 48    D    Demand
# 4996  2023-09-13T15       US48  United States Lower 48    D    Demand
# 4997  2023-09-13T14       US48  United States Lower 48    D    Demand
# 4998  2023-09-13T13       US48  United States Lower 48    D    Demand
# 4999  2023-09-13T12       US48  United States Lower 48    D    Demand
#
#           value    value-units
# 0        423771  megawatthours
# 1        428223  megawatthours
# 2        429868  megawatthours
# 3        432064  megawatthours
# 4        431814  megawatthours
# ...         ...            ...
# 4995  503245.08  megawatthours
# 4996   484268.1  megawatthours
# 4997   468001.4  megawatthours
# 4998  453854.74  megawatthours
# 4999  442337.71  megawatthours
#
# [5000 rows x 7 columns]
